# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data = pd.read_excel('C:/Users/awast/abc.xlsx')
#Basic checks of data

# %%
data.head()
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single            Sales
# 1  E1001006   47   Male           Marketing        Single            Sales
# 2  E1001007   40   Male       Life Sciences       Married            Sales
# 3  E1001009   41   Male     Human Resources      Divorced  Human Resources
# 4  E1001011   27   Male       Life Sciences      Divorced      Development
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4        Developer       Travel_Frequently                10
#
#    EmpEducationLevel  ...  EmpRelationshipSatisfaction  \
# 0                  3  ...                            4
# 1                  4  ...                            4
# 2                  4  ...                            3
# 3                  4  ...                            2
# 4                  2  ...                            3
#
#    TotalWorkExperienceInYears  TrainingTimesLastYear  EmpWorkLifeBalance  \
# 0                          10                      2                   2
# 1                          20                      2                   3
# 2                          20                      2                   3
# 3                          23                      2                   2
# 4                           9                      4                   2
#
#    ExperienceYearsAtThisCompany  ExperienceYearsInCurrentRole  \
# 0                            10                             7
# 1                             7                             7
# 2                            18                            13
# 3                            21                             6
# 4                             9                             7
#
#   YearsSinceLastPromotion  YearsWithCurrManager  Attrition  PerformanceRating
# 0                       0                     8         No                  3
# 1                       1                     7         No                  3
# 2                       1                    12         No                  4
# 3                      12                     6         No                  3
# 4                       1                     7         No                  4
#
# [5 rows x 28 columns]

# %%
data.tail()
# Out:
#      EmpNumber  Age  Gender EducationBackground MaritalStatus EmpDepartment  \
# 1194   E100992   27  Female             Medical      Divorced         Sales
# 1195   E100993   37    Male       Life Sciences        Single   Development
# 1196   E100994   50    Male             Medical       Married   Development
# 1197   E100995   34  Female             Medical        Single  Data Science
# 1198   E100998   24  Female       Life Sciences        Single         Sales
#
#             EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 1194   Sales Executive       Travel_Frequently                 3
# 1195  Senior Developer           Travel_Rarely                10
# 1196  Senior Developer           Travel_Rarely                28
# 1197    Data Scientist           Travel_Rarely                 9
# 1198   Sales Executive           Travel_Rarely                 3
#
#       EmpEducationLevel  ...  EmpRelationshipSatisfaction  \
# 1194                  1  ...                            2
# 1195                  2  ...                            1
# 1196                  1  ...                            3
# 1197                  3  ...                            2
# 1198                  2  ...                            1
#
#       TotalWorkExperienceInYears  TrainingTimesLastYear  EmpWorkLifeBalance  \
# 1194                           6                      3                   3
# 1195                           4                      2                   3
# 1196                          20                      3                   3
# 1197                           9                      3                   4
# 1198                           4                      3                   3
#
#       ExperienceYearsAtThisCompany  ExperienceYearsInCurrentRole  \
# 1194                             6                             5
# 1195                             1                             0
# 1196                            20                             8
# 1197                             8                             7
# 1198                             2                             2
#
#      YearsSinceLastPromotion  YearsWithCurrManager  Attrition  \
# 1194                       0                     4         No
# 1195                       0                     0         No
# 1196                       3                     8         No
# 1197                       7                     7         No
# 1198                       2                     0        Yes
#
#       PerformanceRating
# 1194                  4
# 1195                  3
# 1196                  3
# 1197                  3
# 1198                  2
#
# [5 rows x 28 columns]

# %%
data.columns
# Out:
# Index(['EmpNumber', 'Age', 'Gender', 'EducationBackground', 'MaritalStatus',
#        'EmpDepartment', 'EmpJobRole', 'BusinessTravelFrequency',
#        'DistanceFromHome', 'EmpEducationLevel', 'EmpEnvironmentSatisfaction',
#        'EmpHourlyRate', 'EmpJobInvolvement', 'EmpJobLevel',
#        'EmpJobSatisfaction', 'NumCompaniesWorked', 'OverTime',
#        'EmpLastSalaryHikePercent', 'EmpRelationshipSatisfaction',
#        'TotalWorkExperienceInYears', 'TrainingTimesLastYear',
#        'EmpWorkLifeBalance', 'ExperienceYearsAtThisCompany',
#        'ExperienceYearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'Attrition', 'PerformanceRating'],
#       dtype='object')

# %%
data.shape
# Out:
# (1199, 28)

# %%
#Examine the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1199 entries, 0 to 1198
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   EmpNumber                     1199 non-null   object
#  1   Age                           1199 non-null   int64
#  2   Gender                        1199 non-null   object
#  3   EducationBackground           1199 non-null   object
#  4   MaritalStatus                 1199 non-null   object
#  5   EmpDepartment                 1199 non-null   object
#  6   EmpJobRole                    1199 non-null   object
#  7   BusinessTravelFrequency       1199 non-null   object
#  8   DistanceFromHome              1199 non-null   int64
#  9   EmpEducationLevel             1199 non-null   int64
#  10  EmpEnvironmentSatisfaction    1199 non-null   int64
#  11  EmpHourlyRate                 1199 non-null   int64
#  12  EmpJobInvolvement             1199 non-null   int64
#  13  EmpJobLevel                   1199 non-null   int64
#  14  EmpJobSatisfaction            1199 non-null   int64
#  15  NumCompaniesWorked            1199 non-null   int64
#  16  OverTime                      1199 non-null   object
#  17  EmpLastSalaryHikePercent      1199 non-null   int64
#  18  EmpRelationshipSatisfaction   1199 non-null   int64
#  19  TotalWorkExperienceInYears    1199 non-null   int64
#  20  TrainingTimesLastYear         1199 non-null   int64
#  21  EmpWorkLifeBalance            1199 non-null   int64
#  22  ExperienceYearsAtThisCompany  1199 non-null   int64
#  23  ExperienceYearsInCurrentRole  1199 non-null   int64
#  24  YearsSinceLastPromotion       1199 non-null   int64
#  25  YearsWithCurrManager          1199 non-null   int64
#  26  Attrition                     1199 non-null   object
#  27  PerformanceRating             1199 non-null   int64
# dtypes: int64(19), object(9)
# memory usage: 262.4+ KB

# %%
#Statistica measure of data
data.describe()
# Out:
#                Age  DistanceFromHome  EmpEducationLevel  \
# count  1199.000000       1199.000000        1199.000000
# mean     36.899083          9.160133           2.891576
# std       9.066568          8.177663           1.044065
# min      18.000000          1.000000           1.000000
# 25%      30.000000          2.000000           2.000000
# 50%      36.000000          7.000000           3.000000
# 75%      43.000000         14.000000           4.000000
# max      60.000000         29.000000           5.000000
#
#        EmpEnvironmentSatisfaction  EmpHourlyRate  EmpJobInvolvement  \
# count                 1199.000000    1199.000000        1199.000000
# mean                     2.717264      65.966639           2.731443
# std                      1.089927      20.213028           0.707416
# min                      1.000000      30.000000           1.000000
# 25%                      2.000000      48.000000           2.000000
# 50%                      3.000000      66.000000           3.000000
# 75%                      4.000000      83.000000           3.000000
# max                      4.000000     100.000000           4.000000
#
#        EmpJobLevel  EmpJobSatisfaction  NumCompaniesWorked  \
# count  1199.000000         1199.000000         1199.000000
# mean      2.067556            2.733945            2.660550
# std       1.108296            1.100208            2.465597
# min       1.000000            1.000000            0.000000
# 25%       1.000000            2.000000            1.000000
# 50%       2.000000            3.000000            2.000000
# 75%       3.000000            4.000000            4.000000
# max       5.000000            4.000000            9.000000
#
#        EmpLastSalaryHikePercent  EmpRelationshipSatisfaction  \
# count               1199.000000                  1199.000000
# mean                  15.223520                     2.723937
# std                    3.627259                     1.075460
# min                   11.000000                     1.000000
# 25%                   12.000000                     2.000000
# 50%                   14.000000                     3.000000
# 75%                   18.000000                     4.000000
# max                   25.000000                     4.000000
#
#        TotalWorkExperienceInYears  TrainingTimesLastYear  EmpWorkLifeBalance  \
# count                 1199.000000            1199.000000         1199.000000
# mean                    11.331109               2.787323            2.743953
# std                      7.800387               1.262919            0.699626
# min                      0.000000               0.000000            1.000000
# 25%                      6.000000               2.000000            2.000000
# 50%                     10.000000               3.000000            3.000000
# 75%                     15.000000               3.000000            3.000000
# max                     40.000000               6.000000            4.000000
#
#        ExperienceYearsAtThisCompany  ExperienceYearsInCurrentRole  \
# count                   1199.000000                   1199.000000
# mean                       7.081735                      4.293578
# std                        6.237775                      3.614645
# min                        0.000000                      0.000000
# 25%                        3.000000                      2.000000
# 50%                        5.000000                      3.000000
# 75%                       10.000000                      7.000000
# max                       40.000000                     18.000000
#
#        YearsSinceLastPromotion  YearsWithCurrManager  PerformanceRating
# count              1199.000000           1199.000000         1199.00000
# mean                  2.194329              4.106756            2.94829
# std                   3.222899              3.542531            0.51908
# min                   0.000000              0.000000            2.00000
# 25%                   0.000000              2.000000            3.00000
# 50%                   1.000000              3.000000            3.00000
# 75%                   3.000000              7.000000            3.00000
# max                  15.000000             17.000000            4.00000

# %%
data.describe(include="O")
# Out:
#        EmpNumber Gender EducationBackground MaritalStatus EmpDepartment  \
# count       1199   1199                1199          1199          1199
# unique      1199      2                   6             3             6
# top     E1001000   Male       Life Sciences       Married         Sales
# freq           1    724                 492           548           372
#
#              EmpJobRole BusinessTravelFrequency OverTime Attrition
# count              1199                    1199     1199      1199
# unique               19                       3        2         2
# top     Sales Executive           Travel_Rarely       No        No
# freq                269                     845      846      1021

# %%
#Department wise performance rating
plt.figure(figsize=(20,10),facecolor='white')
sns.violinplot(x='EmpDepartment',y='PerformanceRating',hue=data.Gender,data=data,palette='rocket')
plt.xlabel('EmpDepartment',fontsize=20)
plt.ylabel('PerformanceRating',fontsize=15)
plt.show()

# %%
#Employee department vs performance rating
plt.figure(figsize=(20,10),facecolor='white')
ax = sns.countplot(x='EmpDepartment',hue=data.PerformanceRating,data=data)
for i in ax.patches:
    ax.annotate('{:.0f}'.format(i.get_height()), (i.get_x()+0.06, i.get_height()+2))
plt.title('Employee Departments vs PerformanceRating',fontsize=20)
plt.xlabel('EmpDepartment',fontsize=20)
plt.ylabel('PerformanceRating',fontsize=15)
plt.show()
